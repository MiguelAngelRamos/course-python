# %%
## Los Set

# forma 1 usando llaves {}
colores = { "rojo", "Verde", "Azul"}

numeros = set([1, 2, 3, 3, 4, 5, 100, 100]) # forma 2 usando set()

# %%
print(numeros)
# Out:
# {1, 2, 3, 4, 5, 100}

# %%
# Cuidado! con la trampa del set vacio
nombres = {}
print(type(nombres))
# Out:
# <class 'dict'>

# %%
set_vacio = set()
print(type(set_vacio))
# Out:
# <class 'set'>

# %%
# Métodos Principales

tecnologias = {"Python", "Java", "C#", "JavaScript"}
print(type(tecnologias))
# Out:
# <class 'set'>

# %%
# add() -> Agrega un elemento al set
tecnologias.add("GoLang")
print(tecnologias)
# Out:
# {'Java', 'C#', 'GoLang', 'Python', 'JavaScript'}

# %%
tecnologias.remove("Cobol")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 tecnologias.remove("Cobol")
#
# KeyError: 'Cobol'

# %%
# Esto eliminado todo
tecnologias.clear()
print(tecnologias)
# Out:
# set()
