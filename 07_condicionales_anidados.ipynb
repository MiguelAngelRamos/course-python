# %%
edad = 20
tiene_licencia = True

if edad >=18:
    if tiene_licencia:
        print("Puede conducir.")
    if not tiene_licencia:
        print("No puede conducir sin licencia.")
# Out:
# Puede conducir.

# %%
def verificar_conduccion(edad, tiene_licencia):
    if edad < 18:
        print("No puede conducir, es menor de edad.")
        return # Sale de la funcion
    if not tiene_licencia:
        print("No puede conducir sin licencia.")
        return # Sale de la funcion
    print("Puede conducir.")

# %%
# verificar_conduccion(20, True)  # Salida: Puede conducir.
# verificar_conduccion(20, False) # Salida: No puede conducir sin licencia.
verificar_conduccion(16, False)
# Out:
# No puede conducir, es menor de edad.

# %%
numero = int(input("Ingrese un número: "))
if numero > 0:
    print("El número es positivo.")
elif numero < 0:
    print("El número es negativo.")
else:
    print("El número es cero.")
# Out:
# El número es cero.

# %%
def deposito_bancario():
    print("Bienvenido al depósito bancario.")

# %%
deposito_bancario()

# d_b_avance()  # Esta función de deposito bancario avanzado eso significa la nomenclatura
def d_b_avance():
    pass
# Out:
# Bienvenido al depósito bancario.
